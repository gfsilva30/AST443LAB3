# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.io import fits
from astropy.nddata import CCDData
from astropy.visualization import hist
from ccdproc import *
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime

# %%
# read in dark files
dark0 = CCDData.read('lab3_dark2min.00000026.DARK.FIT', unit='adu')
dark1 = CCDData.read('lab3_dark2min.00000027.DARK.FIT', unit='adu')
dark2 = CCDData.read('lab3_dark2min.00000028.DARK.FIT', unit='adu')
dark3 = CCDData.read('lab3_dark2min.00000029.DARK.FIT', unit='adu')
dark4 = CCDData.read('lab3_dark2min.00000030.DARK.FIT', unit='adu')
dark5 = CCDData.read('lab3_dark2min.00000031.DARK.FIT', unit='adu')
dark6 = CCDData.read('lab3_dark2min.00000032.DARK.FIT', unit='adu')

# combining darks
combined_darks = Combiner([dark0, dark1, dark2, dark3, dark4, dark5, dark6])
master_dark = combined_darks.median_combine()

#Making new FIT file from median array
hdu = fits.PrimaryHDU(master_dark)
hdul = fits.HDUList([hdu])
#hdu.writeto('master_dark2min.DARK.FIT')

#prints dark image
dark_image2min = CCDData.read('master_dark2min.DARK.FIT', unit='adu')
plt.imshow(dark_image2min.data, cmap = 'viridis', vmin= np.mean(master_dark.data) - 3*np.std(master_dark.data), vmax = np.mean(master_dark.data) + 3*np.std(master_dark.data))
plt.colorbar()

# %%
#Plot Master Dark Image Histogram
dark0 = dark_image2min.data.flatten()
hist(dark0, bins=100, label='Dark Image 2min')
plt.grid()
plt.legend()
plt.xlabel('Pixel value')
plt.ylabel('Number of pixels')
plt.semilogy() #y-axis in log-scale
# Out:
# []

# %%
# read in dark files
dark10 = CCDData.read('lab3_dark5min.00000043.DARK.FIT', unit='adu')
dark11 = CCDData.read('lab3_dark5min.00000044.DARK.FIT', unit='adu')
dark12 = CCDData.read('lab3_dark5min.00000045.DARK.FIT', unit='adu')
dark13 = CCDData.read('lab3_dark5min.00000046.DARK.FIT', unit='adu')
dark14 = CCDData.read('lab3_dark5min.00000047.DARK.FIT', unit='adu')

# combining darks
combined_darks = Combiner([dark10, dark11, dark12, dark13, dark14])
master_dark = combined_darks.median_combine()

#Making new FIT file from median array
hdu = fits.PrimaryHDU(master_dark)
hdul = fits.HDUList([hdu])
#hdu.writeto('master_dark5min.DARK.FIT')

#prints dark image
dark_image5min = CCDData.read('master_dark5min.DARK.FIT', unit='adu')
plt.imshow(dark_image5min.data, cmap = 'viridis', vmin= np.mean(master_dark.data) - 3*np.std(master_dark.data), vmax = np.mean(master_dark.data) + 3*np.std(master_dark.data))
plt.colorbar()

# %%
#Plot Master Dark Image Histogram
dark1 = dark_image5min.data.flatten()
hist(dark1, bins=100, label='Dark Image 5min')
plt.grid()
plt.legend()
plt.xlabel('Pixel value')
plt.ylabel('Number of pixels')
plt.semilogy() #y-axis in log-scale
# Out:
# []

# %%
# read in dark files
dark20 = CCDData.read('lab3_dark30sec.00000033.DARK.FIT', unit='adu')
dark21 = CCDData.read('lab3_dark30sec.00000034.DARK.FIT', unit='adu')
dark22 = CCDData.read('lab3_dark30sec.00000035.DARK.FIT', unit='adu')
dark23 = CCDData.read('lab3_dark30sec.00000036.DARK.FIT', unit='adu')
dark24 = CCDData.read('lab3_dark30sec.00000037.DARK.FIT', unit='adu')
dark25 = CCDData.read('lab3_dark30sec.00000038.DARK.FIT', unit='adu')
dark26 = CCDData.read('lab3_dark30sec.00000039.DARK.FIT', unit='adu')
dark27 = CCDData.read('lab3_dark30sec.00000040.DARK.FIT', unit='adu')
dark28 = CCDData.read('lab3_dark30sec.00000041.DARK.FIT', unit='adu')
dark29 = CCDData.read('lab3_dark30sec.00000042.DARK.FIT', unit='adu')

# combining darks
combined_darks = Combiner([dark20, dark21, dark22, dark23, dark24, dark25, dark26, dark27, dark28, dark29])
master_dark = combined_darks.median_combine()

#Making new FIT file from median array
hdu = fits.PrimaryHDU(master_dark)
hdul = fits.HDUList([hdu])
#hdu.writeto('master_dark30sec.DARK.FIT')

#prints dark image
dark_image30sec = CCDData.read('master_dark30sec.DARK.FIT', unit='adu')
plt.imshow(dark_image30sec.data, cmap = 'viridis', vmin= np.mean(master_dark.data) - 3*np.std(master_dark.data), vmax = np.mean(master_dark.data) + 3*np.std(master_dark.data))
plt.colorbar()

# %%
#Plot Master Dark Image Histogram
dark2 = dark_image30sec.data.flatten()
hist(dark2, bins=100, label='Dark Image 30sec')
plt.grid()
plt.legend()
plt.xlabel('Pixel value')
plt.ylabel('Number of pixels')
plt.semilogy() #y-axis in log-scale
# Out:
# []

# %%
# read in flat field files
flat0 = CCDData.read('lab3_flats.00000003.FIT', unit='adu')
flat1 = CCDData.read('lab3_flats_120sec.00000001.FIT', unit='adu')
flat2 = CCDData.read('lab3_flats_120sec.00000003.FIT', unit='adu')
flat3 = CCDData.read('lab3_flats_120sec.00000004.FIT', unit='adu')
flat4 = CCDData.read('lab3_flats_120sec.00000005.FIT', unit='adu')
flat5 = CCDData.read('lab3_flats_120sec.00000006.FIT', unit='adu')

# combining flats
combiner_flats = Combiner([flat0, flat1, flat2, flat3, flat4, flat5])
combined_median_flats = np.array(combiner_flats.median_combine())
mean_flats = np.mean(combined_median_flats)

# create master normed flat
master_flat = combined_median_flats/mean_flats

hdu_flats = fits.PrimaryHDU(master_flat)
hdul_flats = fits.HDUList([hdu_flats])
#hdu_flats.writeto('normed_master_flat.FIT')

#plots image
flat_image = CCDData.read('normed_master_flat.FIT', unit='adu')
plt.imshow(flat_image.data, cmap='viridis', vmin = np.mean(master_flat) - 3*(np.std(master_flat)), vmax= np.mean(master_flat) + 3*(np.std(master_flat)))

# %%
hist(flat_image.data.flatten(), bins=150, label='Dark Image')
plt.grid()
plt.legend()
plt.xlabel('Pixel value')
plt.ylabel('Number of pixels')
# Out:
# Text(0, 0.5, 'Number of pixels')

# %%
#Cutting out the images to keep only the data from the target slit of 50µm
#ds9 was used to determine the physical cut
flat_spectro = flat_image.data[112:185, :]
np.shape(flat_spectro)
# Out:
# (73, 765)

# %%
#Making new FIT file from median array
hdu_flats2 = fits.PrimaryHDU(flat_spectro)
hdul_flats2 = fits.HDUList([hdu_flats2])
#hdu_flats2.writeto('cut_spec.FIT')

# %%
#Displaying the cut spectrum image
spec_image = CCDData.read('cut_spec.FIT', unit='adu')

#Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
mean_spec = np.mean(spec_image.data)
std_spec = np.std(spec_image.data)

#Displaying the cut spectrum image
plt.imshow(spec_image.data, cmap='viridis', vmin=mean_spec-3*std_spec, vmax=mean_spec+3*std_spec)
plt.colorbar()

# %%
#Flatten the spectrum data and plot the flat-field values against the pixel positions
spec_graph = np.median(spec_image.data, axis=0)
x_pos = np.linspace(1,765,765)
plt.plot(x_pos, spec_graph)
plt.xlabel('Pixel Positions along the X-Axis')
plt.ylabel('Flat-Field Values')
# Out:
# Text(0, 0.5, 'Flat-Field Values')

# %%
#Line of Best Fit Calibration
a, b, c, d = np.polyfit(x_pos, spec_graph, deg=3)
xseq = np.linspace(1, 765, 765)
plt.plot(x_pos, spec_graph)
plt.plot(x_pos, a * xseq**3 + b*xseq**2 + c*xseq**1 + d, color="black", lw=1.5, label=f'{np.around(a,15)}*x^3 + {np.around(b,10)}*x^2 + {np.around(c,10)}*x + {np.around(d,5)}')
plt.xlabel('Pixel Positions along the X-Axis')
plt.ylabel('Flat-Field Values')
plt.legend()

# %%
#Calibration 1: Arclamp
flat_arclamp = CCDData.read('lab3_neon.00000002.FIT', unit='adu')

#Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
std_arclamp = np.std(flat_arclamp.data)
mean_arclamp = np.mean(flat_arclamp.data)

#Displaying the flat arclamp image
plt.imshow(flat_arclamp.data, cmap='viridis', vmin=mean_arclamp-3*std_arclamp, vmax=mean_arclamp+3*std_arclamp)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:243, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     242 try:
# --> 243     kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244 except KeyError:
#
# KeyError: 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb Cell 16 line 6
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> #Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> std_arclamp = np.std(flat_arclamp)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> mean_arclamp = np.mean(flat_arclamp)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> #Displaying the flat arclamp image
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> plt.imshow(flat_arclamp.data, cmap='viridis', vmin=mean_arclamp-3*std_arclamp, vmax=mean_arclamp+3*std_arclamp)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3502, in mean(a, axis, dtype, out, keepdims, where)
#    3500         pass
#    3501     else:
# -> 3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:638, in NDArithmeticMixin.mean(self, **kwargs)
#     636 @sharedmethod
#     637 def mean(self, **kwargs):
# --> 638     return self._prepare_then_do_arithmetic(np.mean, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:746, in NDArithmeticMixin._prepare_then_do_arithmetic(self_or_cls, operation, operand, operand2, **kwargs)
#     737     result, init_kwds = cls._arithmetic(
#     738         operand,
#     739         operation,
#     740         operand2,
#     741         **kwargs,
#     742     )
#     743 else:
#     744     # otherwise call the _arithmetic method on self for a collapse operation:
#     745     # for collapse operations, use astropy.utils.masked rather than handle_mask
# --> 746     result, init_kwds = self_or_cls._arithmetic(
#     747         operation,
#     748         operand2,
#     749         **kwargs,
#     750     )
#     752 # Return a new class based on the result
#     753 return cls(result, **init_kwds)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:245, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     243         kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244     except KeyError:
# --> 245         raise KeyError(f"Unknown prefix {splitted[0]} for parameter {i}")
#     247 kwargs = {}
#     249 # First check that the WCS allows the arithmetic operation
#
# KeyError: 'Unknown prefix dtype for parameter dtype'

# %%
#Cutting for slit
cut_arclamp = flat_arclamp.data[112:185, :]
np.shape(cut_arclamp)

#Making new FIT file from median array
hdu_arc = fits.PrimaryHDU(flat_spectro)
hdul_arc = fits.HDUList([hdu_flats2])
#hdu_arc.writeto('cut_arc.FIT')

# %%
arclamp_image = CCDData.read('cut_arc.FIT', unit='adu')

#Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
std_arc = np.std(arclamp_image.data)
mean_arc = np.mean(arclamp_image.data)

#4.4.4 - Displaying the cut arclamp spectrum image
plt.imshow(arclamp_image.data, cmap='viridis', vmin=mean_arc-3*std_arc, vmax=mean_arc+3*std_arc)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:243, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     242 try:
# --> 243     kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244 except KeyError:
#
# KeyError: 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb Cell 18 line 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> #Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> std_arc = np.std(arclamp_image)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> mean_arc = np.mean(arclamp_image)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> #4.4.4 - Displaying the cut arclamp spectrum image
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X32sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> plt.imshow(arclamp_image.data, cmap='viridis', vmin=mean_arc-3*std_arc, vmax=mean_arc+3*std_arc)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3502, in mean(a, axis, dtype, out, keepdims, where)
#    3500         pass
#    3501     else:
# -> 3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:638, in NDArithmeticMixin.mean(self, **kwargs)
#     636 @sharedmethod
#     637 def mean(self, **kwargs):
# --> 638     return self._prepare_then_do_arithmetic(np.mean, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:746, in NDArithmeticMixin._prepare_then_do_arithmetic(self_or_cls, operation, operand, operand2, **kwargs)
#     737     result, init_kwds = cls._arithmetic(
#     738         operand,
#     739         operation,
#     740         operand2,
#     741         **kwargs,
#     742     )
#     743 else:
#     744     # otherwise call the _arithmetic method on self for a collapse operation:
#     745     # for collapse operations, use astropy.utils.masked rather than handle_mask
# --> 746     result, init_kwds = self_or_cls._arithmetic(
#     747         operation,
#     748         operand2,
#     749         **kwargs,
#     750     )
#     752 # Return a new class based on the result
#     753 return cls(result, **init_kwds)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:245, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     243         kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244     except KeyError:
# --> 245         raise KeyError(f"Unknown prefix {splitted[0]} for parameter {i}")
#     247 kwargs = {}
#     249 # First check that the WCS allows the arithmetic operation
#
# KeyError: 'Unknown prefix dtype for parameter dtype'

# %%
print(np.size(arclamp_image.data))
normed_spec = arclamp_image.data/(a * xseq **2 + b*xseq + c)

#4.4.4 - Making new FIT file from median array
hdu_flats3= fits.PrimaryHDU(normed_spec)
hdul_flats3 = fits.HDUList([hdu_flats3])
#hdu_flats3.writeto('cut_arclamp_normed.FIT')
# Out:
# 55845

# %%
cut_arclamp_normed = CCDData.read('cut_arclamp_normed.FIT', unit='adu')

#Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
std_arcnorm = np.std(cut_arclamp_normed.data)
mean_arcnorm = np.mean(cut_arclamp_normed.data)

plt.imshow(cut_arclamp_normed.data, cmap='inferno', vmin=mean_arcnorm-3*std_arcnorm, vmax=mean_arcnorm+3*std_arcnorm)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:243, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     242 try:
# --> 243     kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244 except KeyError:
#
# KeyError: 'dtype'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb Cell 20 line 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> #Finding the Standard Deviation and Mean for vmin and vmax in order to show the image
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> std_arcnorm = np.std(cut_arclamp_normed)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> mean_arcnorm = np.mean(cut_arclamp_normed)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> plt.imshow(cut_arclamp_normed.data, cmap='inferno', vmin=mean_arcnorm-3*std_arcnorm, vmax=mean_arcnorm+3*std_arcnorm)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/gaybee/AST443_LAB3/AST443_Lab3_113181913.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> plt.colorbar()
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3502, in mean(a, axis, dtype, out, keepdims, where)
#    3500         pass
#    3501     else:
# -> 3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:638, in NDArithmeticMixin.mean(self, **kwargs)
#     636 @sharedmethod
#     637 def mean(self, **kwargs):
# --> 638     return self._prepare_then_do_arithmetic(np.mean, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:746, in NDArithmeticMixin._prepare_then_do_arithmetic(self_or_cls, operation, operand, operand2, **kwargs)
#     737     result, init_kwds = cls._arithmetic(
#     738         operand,
#     739         operation,
#     740         operand2,
#     741         **kwargs,
#     742     )
#     743 else:
#     744     # otherwise call the _arithmetic method on self for a collapse operation:
#     745     # for collapse operations, use astropy.utils.masked rather than handle_mask
# --> 746     result, init_kwds = self_or_cls._arithmetic(
#     747         operation,
#     748         operand2,
#     749         **kwargs,
#     750     )
#     752 # Return a new class based on the result
#     753 return cls(result, **init_kwds)
#
# File ~/.local/lib/python3.10/site-packages/astropy/nddata/mixins/ndarithmetic.py:245, in NDArithmeticMixin._arithmetic(self, operation, operand, propagate_uncertainties, handle_mask, handle_meta, uncertainty_correlation, compare_wcs, operation_ignores_mask, axis, **kwds)
#     243         kwds2[splitted[0]][splitted[1]] = kwds[i]
#     244     except KeyError:
# --> 245         raise KeyError(f"Unknown prefix {splitted[0]} for parameter {i}")
#     247 kwargs = {}
#     249 # First check that the WCS allows the arithmetic operation
#
# KeyError: 'Unknown prefix dtype for parameter dtype'

# %%
#THESE VALUES ARE FROM LAB1 GET THE CORRECT VALUES
# creating an array of the pixel values for each emission line in the normed arc lamp spectrum 
pixel_value_spec = np.array([164.829, 195.5, 260.894, 292.722, 348.856, 417.144, 465.755, 486, 588, 541.565, 
                             593.648, 630.685, 662.514, 711.125, 732.537])

# creating an array of an example wavelength for neon's emission lines (wavelength in nm)
ex_wavelength = np.array([540.1, 585.2, 588.2, 603.0, 607.4, 616.4, 621.7, 626.6, 633.4, 638.3, 640.2, 650.6, 
                          659.9, 692.9, 703.2])

# %%
plt.scatter(pixel_value_spec, ex_wavelength)
b, a = np.polyfit(pixel_value_spec, ex_wavelength, deg=1)
xseq = np.linspace(150, 740, 13)
plt.plot(xseq, a + b * xseq, color="k", lw=1.5)
plt.xlabel('X position')
plt.ylabel('Test Wavelength (nm)')
print(a,b)
print(a + b * xseq)

# %%
def residual(a,b, xseq):
    return ex_wavelength - (a + b * xseq)

plt.scatter(pixel_value_spec, residual(537.9405507198353, 0.1801970004564606, xseq))
plt.xlabel('X Position')
plt.ylabel('Test Wavelength (nm)')

# %%
wave = np.array(a + b * xseq)
new2 = np.median(cut_arclamp_normed.data, axis = 0)
print(np.size(new2))
xseq2 = np.linspace(5110, 7400, 765)
wavelength = np.array(a + b * xseq2)
plt.plot(xseq2, new2)
plt.text(5590, 0.40, r'5590 $\AA$', fontsize = 10)
plt.text(5768, 0.07, r'5768 $\AA$', fontsize = 8)
plt.text(6213, 0.07, r'6213 $\AA$', fontsize = 8)
plt.xlabel('Wavelength ($\AA$)')
plt.ylabel('Intensity')

# %%
#Define the Gaussian Function MIGHT NOT NEED THIS
def g(sigma,u,x):
    return 1/(sigma*(np.sqrt(2*np.pi))) * np.exp(-(x - u)**2 / (2*sigma**2))
